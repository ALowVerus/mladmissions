# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import warnings
import seaborn as sns
import random
from sklearn.datasets import load_iris
from imblearn.over_sampling import SMOTE
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data=pd.read_csv("navianceScraper/csv.csv")

# %%
data.head()
# Out:
#   type  act  sat2400  gpaWeighted  gpaCumulative  satConcorded  resultCode
# 0   RD   21     1590       3.2844         3.1120          1150           1
# 1   RD   21     1590       3.2844         3.1120          1150           1
# 2   EA    0     2030       3.9161         3.9161          1430           1
# 3   EA    0     2080       4.0000         4.0000          1450           1
# 4   EA    0     1990       2.9241         2.9241          1400           2

# %%
data['resultCode']=data['resultCode'].apply(lambda x: False if x =="2" else True)

# %%
sns.countplot("resultCode", data=data)
plt.show()

# %%
train_y = data.resultCode

train_x = train_x.drop(train_x[train_x.sat2400 <= 0].index)
train_x = pd.DataFrame(data.drop(["resultCode", "type"], axis=1)).reset_index(drop=True)

# %%
train_x
# Out:
#     act  sat2400  gpaWeighted  gpaCumulative  satConcorded
# 0    21     1590       3.2844         3.1120          1150
# 1    21     1590       3.2844         3.1120          1150
# 2     0     2030       3.9161         3.9161          1430
# 3     0     2080       4.0000         4.0000          1450
# 4     0     1990       2.9241         2.9241          1400
# 5     0     1710       3.2355         3.2355          1230
# 6     0     2300       3.8968         3.8968          1560
# 7     0     1630       3.3482         3.3482          1180
# 8    27     2010       3.8983         3.8983          1410
# 9     0     2050       3.0454         3.0454          1440
# 10    0     2200       3.4000         3.4000          1510
# 11    0     2230       3.5129         3.5129          1530
# 12   27     1780       3.8625         3.8625          1270
# 13    0     1640       3.0714         3.0714          1180
# 14    0     2070       3.5910         3.5910          1450
# 15    0     2000       4.1892         4.1892          1410
# 16   27     1860       3.7589         3.7589          1320
# 17    0     1480       3.4191         3.4191          1080
# 18    0     2270       4.0543         4.0543          1550
# 20    0     1630       2.9035         2.9035          1180
# 21    0     1860       3.5543         3.5543          1320
# 22    0     1920       3.7035         3.7035          1360
# 23    0     1790       3.1354         3.1354          1280
# 24    0     2050       3.8946         3.8946          1440
# 25   31     2080       4.0333         4.0333          1450
# 26    0     1730       3.1578         3.1578          1240
# 27   26     1770       3.6836         3.6836          1270
# 28    0     1990       3.4340         3.4340          1400
# 29   31     1770       4.1684         4.1684          1270
# 30    0     2200       4.1393         4.1393          1510
# 31   26     1950       2.8818         2.8818          1380
# 32    0     1840       3.7232         3.7232          1310
# 33   31     1770       4.1684         4.1684          1270
# 34   22     2120       3.4839         3.4839          1480
# 35    0     2110       4.2589         4.2589          1470
# 36    0     2120       4.0071         4.0071          1480
# 37    0     2080       3.6911         3.6911          1450
# 38    0     1760       4.0321         4.0321          1260
# 39    0     1710       3.6089         3.6089          1230
# 40    0     2000       4.0074         4.0074          1410
# 41    0     1880       3.7145         3.7145          1340

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(train_y==True)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(train_y==False)))

sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_sample(train_x, train_y.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==True)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==False)))
# Out:
# Before OverSampling, counts of label '1': 28
# Before OverSampling, counts of label '0': 0
#
# After OverSampling, the shape of train_X: (56, 5)
# After OverSampling, the shape of train_y: (56,)
#
# After OverSampling, counts of label '1': 28
# After OverSampling, counts of label '0': 0

# %%
train_x.shape
# Out:
# (45, 5)
